# %%
'''Links for help:
https://github.com/python-telegram-bot/python-telegram-bot/blob/master/README.rst
'''

def main():
    from telegram.ext import Updater, CommandHandler
    import logging

    updater = Updater(token='1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8', 
                        use_context=True)
    logging.basicConfig(level=logging.DEBUG,
                        format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    
    def start(update, context):
        context.bot.send_message(chat_id=update.effective_chat.id, 
                            text="Привет! Теперь ты можешь воспользоваться мной.")
    def helpme(update, context):
        context.bot.send_message(chat_id=update.effective_chat.id, 
                            text="Чувак, подожди, помощи пока не жди.")
        
    dispatcher = updater.dispatcher
    start_handler = CommandHandler('start', start)
    helpme_handler = CommandHandler('help', helpme)
    dispatcher.add_handler(start_handler)
    dispatcher.add_handler(helpme_handler)

    updater.start_polling()

if __name__ == '__main__':
    main()
# Out:
# 2020-04-03 16:17:40,060 - telegram.ext.dispatcher - DEBUG - Setting singleton dispatcher as None
# 2020-04-03 16:17:40,062 - telegram.bot - DEBUG - Entering: get_me
# 2020-04-03 16:17:40,063 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.telegram.org
# 2020-04-03 16:17:45,800 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "GET /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getMe HTTP/1.1" 200 204
# 2020-04-03 16:17:45,802 - telegram.bot - DEBUG - {'id': 1157983371, 'first_name': 'PlantStationBot', 'is_bot': True, 'username': 'plantstation_bot'}
# 2020-04-03 16:17:45,803 - telegram.bot - DEBUG - Exiting: get_me
# 2020-04-03 16:17:45,805 - JobQueue - DEBUG - JobQueue thread started
# 2020-04-03 16:17:45,807 - telegram.ext.updater - DEBUG - Bot:1157983371:dispatcher - started
# 2020-04-03 16:17:45,810 - telegram.ext.updater - DEBUG - Bot:1157983371:updater - started
# 2020-04-03 16:17:45,816 - telegram.ext.updater - DEBUG - Updater thread started (polling)
# 2020-04-03 16:17:45,816 - telegram.ext.dispatcher - DEBUG - Dispatcher started
# 2020-04-03 16:17:45,817 - telegram.ext.updater - DEBUG - Start network loop retry bootstrap del webhook
# 2020-04-03 16:17:45,821 - telegram.bot - DEBUG - Entering: delete_webhook
# 2020-04-03 16:17:45,883 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/deleteWebhook HTTP/1.1" 200 68
# 2020-04-03 16:17:45,884 - telegram.bot - DEBUG - True
# 2020-04-03 16:17:45,885 - telegram.bot - DEBUG - Exiting: delete_webhook
# 2020-04-03 16:17:45,886 - telegram.ext.updater - DEBUG - Bootstrap done
# 2020-04-03 16:17:45,887 - telegram.ext.updater - DEBUG - Start network loop retry getting Updates
# 2020-04-03 16:17:45,888 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,934 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,935 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (248): api.telegram.org
# 2020-04-03 16:17:48,974 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,975 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (246): api.telegram.org
# 2020-04-03 16:17:48,978 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,979 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (249): api.telegram.org
# 2020-04-03 16:17:48,987 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,988 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (248): api.telegram.org
# 2020-04-03 16:17:48,989 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:48,992 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (253): api.telegram.org
# 2020-04-03 16:17:49,135 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,136 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (251): api.telegram.org
# 2020-04-03 16:17:49,140 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,141 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (249): api.telegram.org
# 2020-04-03 16:17:49,238 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,238 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (249): api.telegram.org
# 2020-04-03 16:17:49,239 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,242 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (249): api.telegram.org
# 2020-04-03 16:17:49,340 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getUpdates HTTP/1.1" 409 143
# 2020-04-03 16:17:49,341 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:49,342 - telegram.ext.dispatcher - DEBUG - Processing Update: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:49,343 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 249, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:49,475 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,476 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (245): api.telegram.org
# 2020-04-03 16:17:49,481 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:49,482 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (245): api.telegram.org
# 2020-04-03 16:17:50,173 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:50,174 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (248): api.telegram.org
# 2020-04-03 16:17:50,329 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAEjsEehirym-KjUYr5Mbl8xRlXOmvQfHWQ/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,330 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAEjsEehirym-KjUYr5Mbl8xRlXOmvQfHWQ/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,331 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAEjsEehirym-KjUYr5Mbl8xRlXOmvQfHWQ/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,332 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,334 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,335 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,339 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,346 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:50,343 - telegram.bot - DEBUG - Entering: get_updates
# 2020-04-03 16:17:50,345 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,341 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,350 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:50,352 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:50,583 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAEjsEehirym-KjUYr5Mbl8xRlXOmvQfHWQ/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,585 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,588 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,589 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:50,906 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAHMyu0ekIDXZ1mewzG4A1IH0rd5KbFn7to/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,907 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,909 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,911 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:50,922 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAHMyu0ekIDXZ1mewzG4A1IH0rd5KbFn7to/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:50,923 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:50,926 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:50,927 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:51,119 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1109002786:AAEjsEehirym-KjUYr5Mbl8xRlXOmvQfHWQ/getUpdates HTTP/1.1" 401 58
# 2020-04-03 16:17:51,121 - telegram.ext.updater - ERROR - Error while getting Updates: Unauthorized
# 2020-04-03 16:17:51,123 - telegram.ext.dispatcher - DEBUG - Processing Update: Unauthorized
# 2020-04-03 16:17:51,124 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 243, in _request_wrapper
#     raise Unauthorized(message)
# telegram.error.Unauthorized: Unauthorized
# 2020-04-03 16:17:52,448 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getUpdates HTTP/1.1" 409 143
# 2020-04-03 16:17:52,449 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,451 - telegram.ext.dispatcher - DEBUG - Processing Update: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,452 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 249, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,462 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getUpdates HTTP/1.1" 409 143
# 2020-04-03 16:17:52,462 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getUpdates HTTP/1.1" 409 143
# 2020-04-03 16:17:52,463 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,465 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,467 - telegram.ext.dispatcher - DEBUG - Processing Update: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,471 - telegram.ext.dispatcher - DEBUG - Processing Update: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,474 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 249, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,472 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 249, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,713 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "POST /bot1157983371:AAEzM_LHvpEyLRHAGnpHZfa0tZkH_Nfm0H8/getUpdates HTTP/1.1" 409 143
# 2020-04-03 16:17:52,714 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,717 - telegram.ext.dispatcher - DEBUG - Processing Update: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2020-04-03 16:17:52,718 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 378, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\ext\updater.py", line 339, in polling_action_cb
#     allowed_updates=allowed_updates)
#   File "<C:\Users\Lydia\anaconda3\lib\site-packages\decorator.py:decorator-gen-157>", line 2, in get_updates
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 67, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\bot.py", line 2067, in get_updates
#     result = self._request.post(url, data, timeout=float(read_latency) + float(timeout))
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 334, in post
#     **urlopen_kwargs)
#   File "C:\Users\Lydia\anaconda3\lib\site-packages\telegram\utils\request.py", line 249, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
