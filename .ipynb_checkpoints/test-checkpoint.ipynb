# %%
import telegram
bot = telegram.Bot(token='1109002786:AAHTKe42PvpxUfqCOfzekGEabJ83QQIWQcE')
print(bot.get_me())
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     616                                                   body=body, headers=headers,
# --> 617                                                   chunked=chunked)
#     618
#
# ~\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     359         try:
# --> 360             self._validate_conn(conn)
#     361         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in _validate_conn(self, conn)
# ...
